# %% [markdown]
# <a href="https://colab.research.google.com/github/caiomagro89/learning_phyton3/blob/main/C%C3%B3pia_de_Lista_e_tupla.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#lista é mutável
lista_compras = ['x', 'y', 't']
print (lista_compras)

lista_compras.append ('a')
print (lista_compras)

lista_compras.remove('y')
print(lista_compras)

print()

#tupla é imutável
coordenadas_gps = ('22°', '33°')
print('Latitude', coordenadas_gps [0])
print('Longitude', coordenadas_gps [1])
# Out:
# ['x', 'y', 't']
# ['x', 'y', 't', 'a']
# ['x', 't', 'a']
#
# Latitude 22°
# Longitude 33°
